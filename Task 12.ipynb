# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats
from scipy.stats import chi2, chi2_contingency
import scipy.stats
from scipy.stats import t
from scipy.stats import norm
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
dataset = pd.read_csv("data.csv")

# %%
dataset
# Out:
#          Unnamed: 0              Id  ... winPoints winPlacePerc
# 0           2093518  a3e3cea9f2e314  ...      1525       0.0667
# 1           3701672  43e4be7ad72cc7  ...      1516       0.5862
# 2           2059784  9a68690e31fdff  ...         0       0.8105
# 3           1302036  b147e1bd448fc4  ...      1515       0.5556
# 4            297180  d818b4edd59612  ...         0       0.6429
# ...             ...             ...  ...       ...          ...
# 1111737     4209703  43739241d6a8e8  ...         0       0.3929
# 1111738     4311549  d57c8a22a9e38b  ...         0       0.8542
# 1111739     3521011  c7ad131758ba55  ...         0       0.7174
# 1111740     2138826  8237d06ea2c508  ...         0       0.9000
# 1111741      609836  9beb0064c56445  ...      1611       1.0000
#
# [1111742 rows x 30 columns]

# %%
dataset = dataset.drop(["Unnamed: 0"], axis = 1)

# %%
dataset
# Out:
#                      Id         groupId  ... winPoints  winPlacePerc
# 0        a3e3cea9f2e314  c9f6eaa81245b5  ...      1525        0.0667
# 1        43e4be7ad72cc7  521836de101ee8  ...      1516        0.5862
# 2        9a68690e31fdff  4a72ffa2cebd90  ...         0        0.8105
# 3        b147e1bd448fc4  9a8991656b3fea  ...      1515        0.5556
# 4        d818b4edd59612  eece87c8b846b3  ...         0        0.6429
# ...                 ...             ...  ...       ...           ...
# 1111737  43739241d6a8e8  afb7c87045825e  ...         0        0.3929
# 1111738  d57c8a22a9e38b  85e0624ddd2cb0  ...         0        0.8542
# 1111739  c7ad131758ba55  b3759687b385b3  ...         0        0.7174
# 1111740  8237d06ea2c508  13a05023ab7735  ...         0        0.9000
# 1111741  9beb0064c56445  5cfa1834dc5b11  ...      1611        1.0000
#
# [1111742 rows x 29 columns]

# %%
dataset.describe()
# Out:
#             assists        boosts  ...     winPoints  winPlacePerc
# count  1.111742e+06  1.111742e+06  ...  1.111742e+06  1.111741e+06
# mean   2.336738e-01  1.106655e+00  ...  6.057065e+02  4.727868e-01
# std    5.894028e-01  1.716050e+00  ...  7.395140e+02  3.073771e-01
# min    0.000000e+00  0.000000e+00  ...  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  ...  0.000000e+00  2.000000e-01
# 50%    0.000000e+00  0.000000e+00  ...  0.000000e+00  4.583000e-01
# 75%    0.000000e+00  2.000000e+00  ...  1.495000e+03  7.407000e-01
# max    1.700000e+01  2.400000e+01  ...  2.002000e+03  1.000000e+00
#
# [8 rows x 25 columns]

# %%
dataset.head(5)
# Out:
#                Id         groupId  ... winPoints  winPlacePerc
# 0  a3e3cea9f2e314  c9f6eaa81245b5  ...      1525        0.0667
# 1  43e4be7ad72cc7  521836de101ee8  ...      1516        0.5862
# 2  9a68690e31fdff  4a72ffa2cebd90  ...         0        0.8105
# 3  b147e1bd448fc4  9a8991656b3fea  ...      1515        0.5556
# 4  d818b4edd59612  eece87c8b846b3  ...         0        0.6429
#
# [5 rows x 29 columns]

# %%
numerical_columns = list(dataset.describe().columns)

# %%
categorical_columns = [i for i in dataset.columns if i not in numerical_columns]

# %%
categorical_columns
# Out:
# ['Id', 'groupId', 'matchId', 'matchType']

# %% [markdown]
# ### PDF

# %%
f, ax = plt.subplots(5, 5, sharey=False ,figsize=(30, 30))
j = 0
for i in numerical_columns:
  k = int(j / 5)
  t = j % 5
  sns.distplot(dataset.loc[:, i], ax=ax[k, t])
  j+=1
f.tight_layout(pad=1.5)
plt.show()

# %% [markdown]
# ### Box Plot

# %%
f, ax = plt.subplots(5, 5, sharey=False ,figsize=(30, 30))
j = 0
for i in numerical_columns:
  k = int(j / 5)
  t = j % 5
  sns.boxplot(dataset.loc[:, i], ax=ax[k, t])
  j+=1
f.tight_layout(pad=1.5)
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
f, ax = plt.subplots(5, 5, sharey=False ,figsize=(30, 30))
j = 0
for i in numerical_columns:
  k = int(j / 5)
  t = j % 5
  sns.scatterplot( dataset.loc[:, "winPlacePerc"], dataset.loc[:, i], ax=ax[k, t]).set_title(f"{i} vs winPlacePerc")
  j+=1
f.tight_layout(pad=1.8)
plt.show()

# %% [markdown]
# #Categorical Data

# %%
dataset["matchType"].unique()
# Out:
# array(['squad-fpp', 'solo-fpp', 'solo', 'duo', 'duo-fpp', 'squad',
#        'normal-squad-fpp', 'normal-duo-fpp', 'normal-solo-fpp',
#        'crashfpp', 'crashtpp', 'normal-squad', 'flaretpp', 'flarefpp',
#        'normal-duo', 'normal-solo'], dtype=object)

# %%
plt.figure(figsize=(25, 25))
sns.histplot(dataset.loc[:, "matchType"])
plt.show()
